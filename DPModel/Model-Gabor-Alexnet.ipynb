# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
root_dir = "/content/gdrive/My Drive/MachineLearning/PlantIll/"
base_dir = root_dir + 'DPModel'

# %%
# !pip install -q torch==1.0.0 torchvision
# Out:
#      |████████████████████████████████| 591.8MB 30kB/s
# ERROR: torchvision 0.4.1+cu100 has requirement torch==1.3.0, but you'll have torch 1.0.0 which is incompatible.

# %%
from fastai import *
from fastai.vision import *
from fastai.widgets import *
import torchvision.models
import torch
from torch.nn.parameter import Parameter
from torch.nn import functional as F
from torch.nn.modules.conv import _ConvNd
from torch.nn.modules.utils import _pair
import torch.nn as nn

# %%
# %reload_ext autoreload 
# %autoreload 2
# %matplotlib inline

# %%
#change directory to where we have our project
import os 
os.getcwd()
os.chdir('/content/gdrive/My Drive/MachineLearning/PlantIll')

# %% [markdown]
# # Getting the data

# %%
## our datapath
path = Path('/content/gdrive/My Drive/Datasets/PlantVillage')
dest = path
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/Datasets/PlantVillage/val'),
#  PosixPath('/content/gdrive/My Drive/Datasets/PlantVillage/train'),
#  PosixPath('/content/gdrive/My Drive/Datasets/PlantVillage/models'),
#  PosixPath('/content/gdrive/My Drive/Datasets/PlantVillage/tmp.pth'),
#  PosixPath('/content/gdrive/My Drive/Datasets/PlantVillage/test.jpg')]

# %%
##### Data **augmentation** 
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %%
np.random.seed(42)
src  = ImageList.from_folder(path)

# %%
sd = (src.split_by_folder(train='train', valid='val'))

# %%
labellists =(sd.label_from_folder())

# %%
##batch size 
bs= 128
## we will use it in progrissive resizing at the beggining it was 256//2
img_size = 256//2

# %%
labellists = (labellists.transform(tfms , size=img_size))

# %%
## our data bunch, it contains ou data loaders 
data =  labellists.databunch(bs=bs).normalize(imagenet_stats)

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy', 'background']
# (39, 39)

# %% [markdown]
# # Our Model

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
#https://github.com/iKintosh/GaborNet

class GaborConv2d(_ConvNd):

    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0, dilation=1, groups=1, bias=False):
        kernel_size = _pair(kernel_size)
        stride = _pair(stride)
        padding = _pair(padding)
        dilation = _pair(dilation)

        super(GaborConv2d, self).__init__(in_channels, out_channels, kernel_size, stride, padding, dilation, False, _pair(0), groups, bias)
        self.freq = nn.Parameter((3.14/2)*1.41**(-torch.randint(0, 5, (out_channels, in_channels))).type(torch.Tensor))
        self.theta = nn.Parameter((3.14/8)*torch.randint(0, 8, (out_channels, in_channels)).type(torch.Tensor))
        self.psi = nn.Parameter(3.14*torch.rand(out_channels, in_channels))
        self.sigma = nn.Parameter(3.14/self.freq)
        self.x0 = torch.ceil(torch.Tensor([self.kernel_size[0]/2]))[0]
        self.y0 = torch.ceil(torch.Tensor([self.kernel_size[1]/2]))[0]

    def forward(self, input):
        y, x = torch.meshgrid([torch.linspace(-self.x0+1, self.x0, self.kernel_size[0]), torch.linspace(-self.y0+1, self.y0, self.kernel_size[1])])
        x = x.to(device)
        y = y.to(device)
        weight = torch.empty(self.weight.shape, requires_grad=False).to(device)
        for i in range(self.out_channels):
            for j in range(self.in_channels):
                sigma = self.sigma[i, j].expand_as(y)
                freq = self.freq[i, j].expand_as(y)
                theta = self.theta[i, j].expand_as(y)
                psi = self.psi[i, j].expand_as(y)

                rotx = x * torch.cos(theta) + y * torch.sin(theta)
                roty = -x * torch.sin(theta) + y * torch.cos(theta)

                g = torch.zeros(y.shape)

                g = torch.exp(-0.5 * ((rotx ** 2 + roty ** 2) / (sigma + 1e-3) ** 2))
                g = g * torch.cos(freq * rotx + psi)
                g = g / (2*3.14*sigma**2)
                weight[i, j] = g
                self.weight.data[i, j] = g
        return F.conv2d(input, weight, self.bias, self.stride, self.padding, self.dilation, self.groups)

# %%
gabor_model = torchvision.models.alexnet(pretrained = True)
nf = data.c # number of output classes in your data

# %%
for param in gabor_model.parameters():
  param.requires_grad = False

# %%
num_ftrs2 = gabor_model.classifier[6].in_features
gabor_model.classifier[6] = nn.Linear(num_ftrs2, nf)

# %%
gabor_model.features[0]
# Out:
# Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))

# %%
gabor_model.features[0] = GaborConv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))

# %%
gabor_model = gabor_model.cuda()

# %%
## fbeta is F1 score fbeta,
learn = Learner(data, gabor_model, metrics=[accuracy])

# %%
learn.model

# %%
learn.summary()
# Out:
# AlexNet
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# GaborConv2d          [64, 31, 31]         23,232     True
# ______________________________________________________________________
# ReLU                 [64, 31, 31]         0          False
# ______________________________________________________________________
# MaxPool2d            [64, 15, 15]         0          False
# ______________________________________________________________________
# Conv2d               [192, 15, 15]        307,392    False
# ______________________________________________________________________
# ReLU                 [192, 15, 15]        0          False
# ______________________________________________________________________
# MaxPool2d            [192, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [384, 7, 7]          663,936    False
# ______________________________________________________________________
# ReLU                 [384, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [256, 7, 7]          884,992    False
# ______________________________________________________________________
# ReLU                 [256, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [256, 7, 7]          590,080    False
# ______________________________________________________________________
# ReLU                 [256, 7, 7]          0          False
# ______________________________________________________________________
# MaxPool2d            [256, 3, 3]          0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [256, 6, 6]          0          False
# ______________________________________________________________________
# Dropout              [9216]               0          False
# ______________________________________________________________________
# Linear               [4096]               37,752,832 False
# ______________________________________________________________________
# ReLU                 [4096]               0          False
# ______________________________________________________________________
# Dropout              [4096]               0          False
# ______________________________________________________________________
# Linear               [4096]               16,781,312 False
# ______________________________________________________________________
# ReLU                 [4096]               0          False
# ______________________________________________________________________
# Linear               [39]                 159,783    True
# ______________________________________________________________________
#
# Total params: 57,163,559
# Total trainable params: 183,015
# Total non-trainable params: 56,980,544
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# # Train the model

# %%
learn.fit_one_cycle(7, max_lr=slice(1e-3, 4e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.872197</td>
#       <td>2.586249</td>
#       <td>0.318843</td>
#       <td>41:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.021209</td>
#       <td>1.757308</td>
#       <td>0.503249</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.700578</td>
#       <td>1.440992</td>
#       <td>0.588799</td>
#       <td>04:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.493721</td>
#       <td>1.279278</td>
#       <td>0.627785</td>
#       <td>04:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.377204</td>
#       <td>1.179361</td>
#       <td>0.659653</td>
#       <td>04:21</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.315999</td>
#       <td>1.133259</td>
#       <td>0.679455</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.316300</td>
#       <td>1.116553</td>
#       <td>0.681467</td>
#       <td>04:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
#learn.save('gabor-AlexNet-weight-1')

# %%
print("Plotting Losses")
learn.recorder.plot_losses()
# Out:
# Plotting Losses

# %%
print("Plotting metrics")
learn.recorder.plot_metrics()
# Out:
# Plotting metrics

# %%
print("Plotting LR")
learn.recorder.plot_lr()
# Out:
# Plotting LR

# %%
learn.load('gabor-AlexNet-weight-1');

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(7, max_lr=slice(1e-3, 6e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.875470</td>
#       <td>0.857008</td>
#       <td>0.744740</td>
#       <td>07:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.781015</td>
#       <td>0.686802</td>
#       <td>0.788521</td>
#       <td>07:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.600263</td>
#       <td>0.568676</td>
#       <td>0.821009</td>
#       <td>07:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.417378</td>
#       <td>0.359859</td>
#       <td>0.884282</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.250892</td>
#       <td>0.173895</td>
#       <td>0.944307</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.146363</td>
#       <td>0.132115</td>
#       <td>0.956528</td>
#       <td>07:43</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.091760</td>
#       <td>0.105403</td>
#       <td>0.964882</td>
#       <td>08:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
#learn.save('gabor-AlexNet-weight-2')

# %%
# before we start the last phase of training we change img_size = 256//2 to img_size = 256
# this change is called progrissive resizing in fastai this method helps
# the model to learn and get a better accuracy

# %%
##batch size 
bs= 128
## we will use it in progrissive resizing at the beggining it was 256//2
img_size = 256

# %%
labellists = (labellists.transform(tfms , size=img_size))
data =  labellists.databunch(bs=bs).normalize(imagenet_stats)

# %%
gabor_model = torchvision.models.alexnet()
nf = data.c # number of output classes in your data

# %%
for param in gabor_model.parameters():
  param.requires_grad = False

# %%
num_ftrs2 = gabor_model.classifier[6].in_features
gabor_model.classifier[6] = nn.Linear(num_ftrs2, nf)

# %%
gabor_model.features[0] = GaborConv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))

# %%
gabor_model = gabor_model.cuda()

# %%
learn = Learner(data, gabor_model, metrics=[accuracy])

# %%
learn.load('gabor-AlexNet-weight-2');

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(7, max_lr=slice(1e-3, 6e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.166604</td>
#       <td>0.190782</td>
#       <td>0.938583</td>
#       <td>08:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.409870</td>
#       <td>0.374145</td>
#       <td>0.879951</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.339063</td>
#       <td>0.336855</td>
#       <td>0.897432</td>
#       <td>07:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.227184</td>
#       <td>0.212921</td>
#       <td>0.932859</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.166463</td>
#       <td>0.151294</td>
#       <td>0.953125</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.082192</td>
#       <td>0.087193</td>
#       <td>0.973082</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.057536</td>
#       <td>0.072227</td>
#       <td>0.977723</td>
#       <td>07:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
#learn.save('gabor-AlexNet-weight-3')

# %%
learn.load('gabor-AlexNet-weight-3');

# %%
learn.freeze_to(-3)
learn.fit_one_cycle(10, max_lr=slice(1e-3, 6e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.087388</td>
#       <td>0.119116</td>
#       <td>0.963335</td>
#       <td>06:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.228588</td>
#       <td>0.216913</td>
#       <td>0.931776</td>
#       <td>06:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.305926</td>
#       <td>0.309175</td>
#       <td>0.907178</td>
#       <td>06:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.268301</td>
#       <td>0.245931</td>
#       <td>0.925588</td>
#       <td>06:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.226003</td>
#       <td>0.204435</td>
#       <td>0.937655</td>
#       <td>06:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.164174</td>
#       <td>0.128772</td>
#       <td>0.961324</td>
#       <td>06:44</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.123448</td>
#       <td>0.106072</td>
#       <td>0.965656</td>
#       <td>06:44</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.084715</td>
#       <td>0.093983</td>
#       <td>0.971071</td>
#       <td>06:41</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.050025</td>
#       <td>0.059472</td>
#       <td>0.982828</td>
#       <td>06:40</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.034094</td>
#       <td>0.057959</td>
#       <td>0.981745</td>
#       <td>06:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
#learn.save('gabor-AlexNet-weight-4')
learn.save('gabor-AlexNet-weight-4.1')

# %%
learn.load('gabor-AlexNet-weight-4');

# %%
learn.unfreeze()
learn.fit_one_cycle(7, max_lr=slice(1e-3, 6e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.111145</td>
#       <td>0.132527</td>
#       <td>0.960551</td>
#       <td>06:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.247194</td>
#       <td>0.194268</td>
#       <td>0.941213</td>
#       <td>06:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.232105</td>
#       <td>0.166328</td>
#       <td>0.949876</td>
#       <td>06:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.147905</td>
#       <td>0.143837</td>
#       <td>0.960396</td>
#       <td>06:42</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.104936</td>
#       <td>0.087316</td>
#       <td>0.974010</td>
#       <td>06:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.068177</td>
#       <td>0.070572</td>
#       <td>0.978960</td>
#       <td>06:48</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.039585</td>
#       <td>0.059360</td>
#       <td>0.982209</td>
#       <td>06:30</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('gabor-AlexNet-weight-5')

# %%
print("Plotting Losses")
learn.recorder.plot_losses()
# Out:
# Plotting Losses

# %%
print("Plotting metrics")
learn.recorder.plot_metrics()
# Out:
# Plotting metrics

# %%
print("Plotting LR")
learn.recorder.plot_lr()
# Out:
# Plotting LR

# %%
learn.load('gabor-AlexNet-weight-5');

# %%
#/content/gdrive/My Drive/Datasets/PlantVillage/val/Grape___Black_rot/test.jpg
#/content/gdrive/My Drive/Datasets/PlantVillage/test.jpg
img = open_image(Path('/content/gdrive/My Drive/Datasets/PlantVillage/val/Grape___Black_rot/test.jpg'))
img
# Out:
# Image (3, 256, 256)

# %%
print("Gabor Resnet time --------------")
# %time pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Gabor Resnet time --------------
# CPU times: user 126 ms, sys: 7.98 ms, total: 134 ms
# Wall time: 135 ms
# Category Grape___Black_rot
